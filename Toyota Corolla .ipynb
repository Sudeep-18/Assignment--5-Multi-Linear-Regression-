# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
toyota  = pd.read_csv("ToyotaCorolla.csv",encoding='unicode_escape')

# %%
toyota.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...            1
# 1         10      2002  72937    Diesel  90          1  ...            1
# 2          9      2002  41711    Diesel  90          1  ...            0
# 3          7      2002  48000    Diesel  90          0  ...            0
# 4          3      2002  38500    Diesel  90          0  ...            1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# ...

# %%
toyota=toyota.drop('Model',axis=1)
toyota=toyota.drop('Mfg_Month',axis=1)
toyota=toyota.drop('Mfg_Year',axis=1)
toyota=toyota.drop('Fuel_Type',axis=1)
toyota=toyota.drop('Met_Color',axis=1)
toyota=toyota.drop('Color',axis=1)
toyota=toyota.drop('Automatic',axis=1)
toyota=toyota.drop('Cylinders',axis=1)
toyota=toyota.drop('Mfr_Guarantee',axis=1)
toyota=toyota.drop('BOVAG_Guarantee',axis=1)
toyota=toyota.drop('Guarantee_Period',axis=1)
toyota=toyota.drop('ABS',axis=1)
toyota=toyota.drop('Airbag_1',axis=1)
toyota=toyota.drop('Airbag_2',axis=1)
toyota=toyota.drop('Airco',axis=1)
toyota=toyota.drop('Automatic_airco',axis=1)
toyota=toyota.drop('Boardcomputer',axis=1)
toyota=toyota.drop('CD_Player',axis=1)
toyota=toyota.drop('Central_Lock',axis=1)
toyota=toyota.drop('Powered_Windows',axis=1)
toyota=toyota.drop('Power_Steering',axis=1)
toyota=toyota.drop('Radio',axis=1)
toyota=toyota.drop('Mistlamps',axis=1)
toyota=toyota.drop('Sport_Model',axis=1)
toyota=toyota.drop('Backseat_Divider',axis=1)
toyota=toyota.drop('Metallic_Rim',axis=1)
toyota=toyota.drop('Radio_cassette',axis=1)
toyota=toyota.drop('Tow_Bar',axis=1)

# %%
toyota.head()
# Out:
#    Id  Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0   1  13500         23  46986  90  2000      3      5            210    1165
# 1   2  13750         23  72937  90  2000      3      5            210    1165
# 2   3  13950         24  41711  90  2000      3      5            210    1165
# 3   4  14950         26  48000  90  2000      3      5            210    1165
# 4   5  13750         30  38500  90  2000      3      5            210    1170

# %%
toyota.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1436 non-null   int64
#  1   Price          1436 non-null   int64
#  2   Age_08_04      1436 non-null   int64
#  3   KM             1436 non-null   int64
#  4   HP             1436 non-null   int64
#  5   cc             1436 non-null   int64
#  6   Doors          1436 non-null   int64
#  7   Gears          1436 non-null   int64
#  8   Quarterly_Tax  1436 non-null   int64
#  9   Weight         1436 non-null   int64
# dtypes: int64(10)
# memory usage: 112.3 KB

# %%
toyota.describe()
# Out:
#                 Id         Price    Age_08_04             KM           HP  \
# count  1436.000000   1436.000000  1436.000000    1436.000000  1436.000000
# mean    721.555014  10730.824513    55.947075   68533.259749   101.502089
# std     416.476890   3626.964585    18.599988   37506.448872    14.981080
# min       1.000000   4350.000000     1.000000       1.000000    69.000000
# 25%     361.750000   8450.000000    44.000000   43000.000000    90.000000
# 50%     721.500000   9900.000000    61.000000   63389.500000   110.000000
# 75%    1081.250000  11950.000000    70.000000   87020.750000   110.000000
# max    1442.000000  32500.000000    80.000000  243000.000000   192.000000
#
#                 cc        Doors        Gears  Quarterly_Tax      Weight
# count   1436.00000  1436.000000  1436.000000    1436.000000  1436.00000
# mean    1576.85585     4.033426     5.026462      87.122563  1072.45961
# std      424.38677     0.952677     0.188510      41.128611    52.64112
# ...

# %%
#sns.pairplot(toyota)

# %%
toyota.corr()
# Out:
#                      Id     Price  Age_08_04        KM        HP        cc  \
# Id             1.000000 -0.738250   0.906132  0.273298 -0.109375 -0.117704
# Price         -0.738250  1.000000  -0.876590 -0.569960  0.314990  0.126389
# Age_08_04      0.906132 -0.876590   1.000000  0.505672 -0.156622 -0.098084
# KM             0.273298 -0.569960   0.505672  1.000000 -0.333538  0.102683
# HP            -0.109375  0.314990  -0.156622 -0.333538  1.000000  0.035856
# cc            -0.117704  0.126389  -0.098084  0.102683  0.035856  1.000000
# Doors         -0.130207  0.185326  -0.148359 -0.036197  0.092424  0.079903
# Gears         -0.043343  0.063104  -0.005364  0.015023  0.209477  0.014629
# Quarterly_Tax -0.240821  0.219197  -0.198431  0.278165 -0.298432  0.306996
# Weight        -0.414500  0.581198  -0.470253 -0.028598  0.089614  0.335637
#
#                   Doors     Gears  Quarterly_Tax    Weight
# Id            -0.130207 -0.043343      -0.240821 -0.414500
# ...

# %%
# id  column doesnot make any impact while pridicting price it is better to remove .
toyota = toyota.drop("Id",axis=1)

# %%
toyota.head()
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3      5            210    1165
# 1  13750         23  72937  90  2000      3      5            210    1165
# 2  13950         24  41711  90  2000      3      5            210    1165
# 3  14950         26  48000  90  2000      3      5            210    1165
# 4  13750         30  38500  90  2000      3      5            210    1170

# %%
#Duplicates
toyota.shape
# Out:
# (1436, 9)

# %%
toyota[toyota.duplicated()]
# Out:
#      Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 113  24950          8  13253  116  2000      5      5            234    1320

# %%
df = toyota.drop_duplicates().reset_index(drop=True)
df
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1430   7500         69  20544   86  1300      3      5             69    1025
# 1431  10845         72  19000   86  1300      3      5             69    1015
# 1432   8500         71  17016   86  1300      3      5             69    1015
# 1433   7250         70  16916   86  1300      3      5             69    1015
# 1434   6950         76      1  110  1600      5      5             19    1114
#
# [1435 rows x 9 columns]

# %%
df.shape
# Out:
# (1435, 9)

# %%
#sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'HP', 'cc', 'Doors', 'Gears',
#        'Quarterly_Tax', 'Weight'],
#       dtype='object')

# %%
df = df.rename({"Quarterly_Tax":"QT"},axis=1)
df = df.rename({"Age_08_04":"Age"},axis=1)
df.tail(5 )
# Out:
#       Price  Age     KM   HP    cc  Doors  Gears  QT  Weight
# 1430   7500   69  20544   86  1300      3      5  69    1025
# 1431  10845   72  19000   86  1300      3      5  69    1015
# 1432   8500   71  17016   86  1300      3      5  69    1015
# 1433   7250   70  16916   86  1300      3      5  69    1015
# 1434   6950   76      1  110  1600      5      5  19    1114

# %% [markdown]
# # Prepairing Model

# %%
import statsmodels.formula.api as smf
model = smf.ols("Price~Age+KM+HP+cc+Doors+Gears+Weight+QT",data=df).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     1118.
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):               0.00
# Time:                        19:25:38   Log-Likelihood:                -12366.
# No. Observations:                1435   AIC:                         2.475e+04
# Df Residuals:                    1426   BIC:                         2.480e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -5472.5404   1412.169     -3.875      0.000   -8242.692   -2702.389
# ...

# %%
model.params
# Out:
# Intercept   -5472.540368
# Age          -121.713891
# KM             -0.020737
# HP             31.584612
# cc             -0.118558
# Doors          -0.920189
# Gears         597.715894
# Weight         16.855470
# QT              3.858805
# dtype: float64

# %%
model.tvalues ,"\n",model.pvalues
# Out:
# (Intercept    -3.875273
#  Age         -46.551876
#  KM          -16.552424
#  HP           11.209719
#  cc           -1.316436
#  Doors        -0.023012
#  Gears         3.034563
#  Weight       15.760663
#  QT            2.944198
#  dtype: float64,
#  '\n',
#  Intercept     1.113392e-04
#  Age          1.879217e-288
#  KM            1.994713e-56
#  HP            5.211155e-28
#  cc            1.882393e-01
#  Doors         9.816443e-01
#  Gears         2.452430e-03
#  Weight        1.031118e-51
#  QT            3.290363e-03
#  dtype: float64)

# %% [markdown]
# # Simple Linear Regression Models

# %%
#since p value for door and cc is >0.05 build slr and mlr models

# %%
ml_c = smf.ols("Price~cc",data=df).fit()

# %%
ml_c.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     22.52
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):           2.29e-06
# Time:                        19:25:39   Log-Likelihood:                -13779.
# No. Observations:                1435   AIC:                         2.756e+04
# Df Residuals:                    1433   BIC:                         2.757e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   9053.5368    363.894     24.880      0.000    8339.715    9767.359
# ...

# %%
ml_d = smf.ols("Price~Doors",data= df).fit()

# %%
ml_d.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     49.99
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):           2.40e-12
# Time:                        19:25:39   Log-Likelihood:                -13765.
# No. Observations:                1435   AIC:                         2.753e+04
# Df Residuals:                    1433   BIC:                         2.755e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7916.1452    407.596     19.422      0.000    7116.596    8715.694
# ...

# %%
ml_cd = smf.ols("Price~cc+Doors",data=df).fit()

# %%
ml_cd.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     34.40
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):           2.55e-15
# Time:                        19:25:39   Log-Likelihood:                -13756.
# No. Observations:                1435   AIC:                         2.752e+04
# Df Residuals:                    1432   BIC:                         2.753e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   6568.3395    513.700     12.786      0.000    5560.655    7576.024
# ...

# %% [markdown]
# # Calculating VIF

# %%
rsq_cc=smf.ols("cc~Age+KM+HP+Doors+Gears+QT+Weight",data=df).fit().rsquared
vif_cc=1/(1-rsq_cc)
rsq_age=smf.ols("Age~cc+KM+HP+Doors+Gears+QT+Weight",data=df).fit().rsquared
vif_age = 1/(1-rsq_age)
rsq_km=smf.ols("KM~Age+cc+HP+Doors+Gears+QT+Weight",data=df).fit().rsquared
vif_km=1/(1-rsq_km)
rsq_hp=smf.ols("HP~Age+KM+cc+Doors+Gears+QT+Weight",data=df).fit().rsquared
vif_hp = 1/(1-rsq_hp)
rsq_doors=smf.ols("Doors~Age+KM+HP+cc+Gears+QT+Weight",data=df).fit().rsquared
vif_doors = 1/abs(1-rsq_doors)
rsq_gears=smf.ols("Gears~Age+KM+HP+Doors+cc+QT+Weight",data=df).fit().rsquared
vif_gears = 1/(1-rsq_gears)
rsq_qt=smf.ols("QT~Age+KM+HP+Doors+Gears+cc+Weight",data=df).fit().rsquared
vif_qt = 1/(1-rsq_qt)
rsq_wgt=smf.ols("Weight~Age+KM+HP+Doors+Gears+QT+cc",data=df).fit().rsquared
vif_wgt = 1/(1-rsq_wgt)

# %%
# storing vif values in data frame
d1 = {'variables':['Age','KM','HP','cc','Doors','Gears','QT','Weight'],'VIF':[vif_age,vif_km,vif_hp,vif_cc,vif_doors,vif_gears,vif_qt,vif_wgt]}
vif_frame=pd.DataFrame(d1)
vif_frame
# Out:
#   variables       VIF
# 0       Age  1.876236
# 1        KM  1.757178
# 2        HP  1.419180
# 3        cc  1.163470
# 4     Doors  1.155890
# 5     Gears  1.098843
# 6        QT  2.295375
# 7    Weight  2.487180

# %% [markdown]
# # Residual Analysis
# ## Test For Normality of Residuals(Q-Q plot)

# %%
model.resid
# Out:
# 0      -3291.958871
# 1      -2503.800414
# 2      -2829.635210
# 3      -1455.789389
# 4      -2450.217277
#            ...
# 1430   -1294.255037
# 1431    2552.422658
# 1432      44.565598
# 1433   -1329.222041
# 1434   -3446.087526
# Length: 1435, dtype: float64

# %%
import statsmodels.api as sm
qqplot = sm.qqplot(model.resid,line='q')
plt.title("Normal Q-Q plot of Residuals")
plt.show()

# %%
list(np.where (model.resid<-5000))
# Out:
# [array([190, 191, 220, 600, 959], dtype=int64)]

# %%
list(np.where(model.resid>5000))
# Out:
# [array([109, 146, 522], dtype=int64)]

# %% [markdown]
# # Residual plot for homoscedasticity

# %%
def get_standardized_values(vals) :
    return(vals-vals.mean()/vals.std())

# %%
plt.scatter (get_standardized_values(model.fittedvalues),get_standardized_values(model.resid))
plt.title("Residual plot")
plt.xlabel("Standardized fitted values")
plt.ylabel("Standardized residual values")
plt.show()

# %% [markdown]
# # Residual Vs Regressors

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Age", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "KM", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "HP", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "cc", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Doors", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Gears", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "QT", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Weight", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# # Model Deletion Diagnostics

# %% [markdown]
# # Detecting influencers / outliers

# %% [markdown]
# # Cooks distance

# %%
model_influence = model.get_influence()
(c,_)=model_influence.cooks_distance

# %%
# plot the influencers values using stem plot
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(df)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
# index and value of influencer where c is more than 0.5
(np.argmax(c),np.max(c))
# Out:
# (80, 78.72950582247955)

# %% [markdown]
# # High  influence points

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()

# %%
k = df.shape[1]
n=df.shape[0]
leverage_cutoff = 3*((k+1)/n)
leverage_cutoff
# Out:
# 0.020905923344947737

# %% [markdown]
# - from the above plot it is evident that data point 80 is the influencer

# %%
df[df.index.isin([80])]
# Out:
#     Price  Age     KM   HP     cc  Doors  Gears   QT  Weight
# 80  18950   25  20019  110  16000      5      5  100    1180

# %% [markdown]
# # Improving The Model

# %%
df_new = df.copy()
df_new.head()
# Out:
#    Price  Age     KM  HP    cc  Doors  Gears   QT  Weight
# 0  13500   23  46986  90  2000      3      5  210    1165
# 1  13750   23  72937  90  2000      3      5  210    1165
# 2  13950   24  41711  90  2000      3      5  210    1165
# 3  14950   26  48000  90  2000      3      5  210    1165
# 4  13750   30  38500  90  2000      3      5  210    1170

# %%
# Discard the data point which are influencers and reassign the row number
df1=df_new.drop(df_new.index[[80]],axis=0).reset_index(drop=True)
df1
# Out:
#       Price  Age     KM   HP    cc  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1429   7500   69  20544   86  1300      3      5   69    1025
# 1430  10845   72  19000   86  1300      3      5   69    1015
# 1431   8500   71  17016   86  1300      3      5   69    1015
# 1432   7250   70  16916   86  1300      3      5   69    1015
# 1433   6950   76      1  110  1600      5      5   19    1114
#
# [1434 rows x 9 columns]

# %% [markdown]
# # Build Model

# %%
final_ml_1= smf.ols('Price~Age+KM+HP+cc+Doors+Gears+QT+Weight',data=df1).fit()
final_ml_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.868
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     1172.
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):               0.00
# Time:                        19:25:52   Log-Likelihood:                -12326.
# No. Observations:                1434   AIC:                         2.467e+04
# Df Residuals:                    1425   BIC:                         2.472e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -6197.9334   1383.989     -4.478      0.000   -8912.808   -3483.059
# ...

# %%
(final_ml_1.rsquared,final_ml_1.aic)
# Out:
# (0.8681163912634053, 24669.363894157)

# %%
# Cooks Distance 
model_influence1 = final_ml_1.get_influence()
(c_1,_)=model_influence1.cooks_distance

# %%
(np.argmax(c_1),np.max(c_1))
# Out:
# (219, 2.225351365527139)

# %%
df2 = df1.copy()

# %%
df2=df1.drop(df1.index[[219]],axis=0)

# %%
df2.head()
# Out:
#    Price  Age     KM  HP    cc  Doors  Gears   QT  Weight
# 0  13500   23  46986  90  2000      3      5  210    1165
# 1  13750   23  72937  90  2000      3      5  210    1165
# 2  13950   24  41711  90  2000      3      5  210    1165
# 3  14950   26  48000  90  2000      3      5  210    1165
# 4  13750   30  38500  90  2000      3      5  210    1170

# %%
df3=df2.reset_index()

# %%
df4=df3.drop(['index'],axis=1)

# %%
final_ml_2 = smf.ols("Price~Age+KM+HP+cc+Doors+Gears+QT+Weight",data= df4).fit()
final_ml_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.876
# Method:                 Least Squares   F-statistic:                     1264.
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):               0.00
# Time:                        19:25:53   Log-Likelihood:                -12270.
# No. Observations:                1433   AIC:                         2.456e+04
# Df Residuals:                    1424   BIC:                         2.461e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.018e+04   1398.103     -7.279      0.000   -1.29e+04   -7433.579
# ...

# %%
final_ml_2.rsquared # accuracy increased to 87.6%
# Out:
# 0.8765926307402282

# %%
pred_y = final_ml_2.predict(df4)

# %%
pred_y
# Out:
# 0       16453.715678
# 1       16006.217709
# 2       16428.047478
# 3       16086.340059
# 4       15908.429428
#             ...
# 1428     9014.516216
# 1429     8441.666463
# 1430     8592.508558
# 1431     8710.863036
# 1432    10232.595430
# Length: 1433, dtype: float64
